# %%
from websocket import create_connection
import json
import pprint
import time
import asyncio
import pandas as pd
import re
import numpy as np
import os
import requests

# %%
# with open('test.json') as json_file:
#     data = json.load(json_file)

# json_file_path = "test.json"

# with open(json_file_path, 'r', encoding='utf-8-sig') as j:
#      contents = json.loads(j.read())

# %%
# stocknews_url = 'https://stocknewsapi.com/api/v1?tickers={}&items=50&token=i579pxeya5umabkbyfvasyczrewokx0laezgrbuu'
# response = requests.get(stocknews_url.format('GOOGL'))
# print(response.status_code)

# %%
stocknews_url = 'https://stocknewsapi.com/api/v1?tickers={}&sortby=rank&days=3&items=50&token=i579pxeya5umabkbyfvasyczrewokx0laezgrbuu'
response = requests.get(stocknews_url.format('GOOGL'))
response.status_code
# Out:
# 200

# %%
dct = response.json()
print(dct)
# Out:
# {'data': [{'news_url': 'https://www.cnbc.com/2021/02/22/google-lifts-pause-on-political-ads-that-started-after-capitol-riots.html', 'image_url': 'https://cdn.snapi.dev/images/v1/l/x/106833414-16122051762021-02-01t184429z-1186226185-rc2ujl9k4bp8-rtrmadp-0-alphabet-results-preview.jpeg', 'title': 'Google lifts pause on political ads that started after Capitol riots', 'text': 'Google has been temporarily pausing some advertising in the past year in an effort to prevent exploitation or misinformation, it has said.', 'source_name': 'CNBC', 'date': 'Mon, 22 Feb 2021 10:25:13 -0500', 'topics': [], 'sentiment': 'Neutral', 'type': 'Article', 'tickers': ['GOOG', 'GOOGL']}, {'news_url': 'https://www.reuters.com/article/us-alphabet-advertising/google-to-resume-accepting-political-ads-in-u-s-idUSKBN2AM1SR', 'image_url': 'https://cdn.snapi.dev/images/v1/u/g/m02d20210222t2i1552443647w940fhfwllplsqrlynxmpeh1l0zh.jpg', 'title': 'Google to resume accepting political ads in U.S', 'text': "Alphabet Inc'
# ...
